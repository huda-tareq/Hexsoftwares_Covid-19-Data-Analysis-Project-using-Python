# %% [markdown]
# # covid-19 small dataset analysis

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r"D:\covid_19_project\covid_19_data.csv")

# %%
df
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered
# 0    4/29/2020       NaN     Afghanistan       1939      60        252
# 1    4/29/2020       NaN         Albania        766      30        455
# 2    4/29/2020       NaN         Algeria       3848     444       1702
# 3    4/29/2020       NaN         Andorra        743      42        423
# 4    4/29/2020       NaN          Angola         27       2          7
# ..         ...       ...             ...        ...     ...        ...
# 316  4/29/2020   Wyoming              US        545       7          0
# 317  4/29/2020  Xinjiang  Mainland China         76       3         73
# 318  4/29/2020     Yukon          Canada         11       0          0
# 319  4/29/2020    Yunnan  Mainland China        185       2        181
# 320  4/29/2020  Zhejiang  Mainland China       1268       1       1263
#
# [321 rows x 6 columns]

# %%
df.count()
#there's null data in state
# Out:
# Date         321
# State        140
# Region       321
# Confirmed    321
# Deaths       321
# Recovered    321
# dtype: int64

# %%
df.isnull().sum()
#181 null values in state column
# Out:
# Date           0
# State        181
# Region         0
# Confirmed      0
# Deaths         0
# Recovered      0
# dtype: int64

# %%
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
sns.heatmap(df.isnull())
plt.show()

# %% [markdown]
# ### show the number of confirm , deaths & recoverd cases in each region

# %%
df.head(2)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455

# %%
df.groupby('Region')[['Confirmed','Deaths','Recovered']].sum().sort_values(by=['Confirmed','Deaths','Recovered'], ascending=False).head(20)
# Out:
#                 Confirmed  Deaths  Recovered
# Region
# US                1039909   60967     120720
# Spain              236899   24275     132929
# Italy              203591   27682      71252
# France             166543   24121      49118
# UK                 166441   26166        857
# Germany            161539    6467     120400
# Turkey             117589    3081      44040
# Russia              99399     972      10286
# Iran                93657    5957      73791
# Mainland China      82862    4633      77610
# Brazil              79685    5513      34132
# Canada              52865    3155      20327
# Belgium             47859    7501      11283
# Netherlands         38998    4727        119
# Peru                33931     943      10037
# India               33062    1079       8437
# Switzerland         29407    1716      22600
# Ecuador             24675     883       1557
# Portugal            24505     973       1470
# Saudi Arabia        21402     157       2953

# %% [markdown]
# ### remove all records where confirmed cases is less than 10

# %%
data=df[~(df['Confirmed']<10)]

# %%
data
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered
# 0    4/29/2020       NaN     Afghanistan       1939      60        252
# 1    4/29/2020       NaN         Albania        766      30        455
# 2    4/29/2020       NaN         Algeria       3848     444       1702
# 3    4/29/2020       NaN         Andorra        743      42        423
# 4    4/29/2020       NaN          Angola         27       2          7
# ..         ...       ...             ...        ...     ...        ...
# 316  4/29/2020   Wyoming              US        545       7          0
# 317  4/29/2020  Xinjiang  Mainland China         76       3         73
# 318  4/29/2020     Yukon          Canada         11       0          0
# 319  4/29/2020    Yunnan  Mainland China        185       2        181
# 320  4/29/2020  Zhejiang  Mainland China       1268       1       1263
#
# [304 rows x 6 columns]

# %%
df
# Out:
#           Date     State          Region  Confirmed  Deaths  Recovered
# 0    4/29/2020       NaN     Afghanistan       1939      60        252
# 1    4/29/2020       NaN         Albania        766      30        455
# 2    4/29/2020       NaN         Algeria       3848     444       1702
# 3    4/29/2020       NaN         Andorra        743      42        423
# 4    4/29/2020       NaN          Angola         27       2          7
# ..         ...       ...             ...        ...     ...        ...
# 316  4/29/2020   Wyoming              US        545       7          0
# 317  4/29/2020  Xinjiang  Mainland China         76       3         73
# 318  4/29/2020     Yukon          Canada         11       0          0
# 319  4/29/2020    Yunnan  Mainland China        185       2        181
# 320  4/29/2020  Zhejiang  Mainland China       1268       1       1263
#
# [321 rows x 6 columns]

# %% [markdown]
# ### in which region max num of confirmed cases where recorded

# %%
df.groupby('Region')['Confirmed'].sum().sort_values(ascending=False).head(20)
# Out:
# Region
# US                1039909
# Spain              236899
# Italy              203591
# France             166543
# UK                 166441
# Germany            161539
# Turkey             117589
# Russia              99399
# Iran                93657
# Mainland China      82862
# Brazil              79685
# Canada              52865
# Belgium             47859
# Netherlands         38998
# Peru                33931
# India               33062
# Switzerland         29407
# Ecuador             24675
# Portugal            24505
# Saudi Arabia        21402
# Name: Confirmed, dtype: int64

# %% [markdown]
# ### in which reigon min deaths were recorded

# %%
df.groupby('Region')['Deaths'].sum().sort_values(ascending=True).head(50)
# Out:
# Region
# Cambodia                            0
# Bhutan                              0
# Dominica                            0
# Central African Republic            0
# Eritrea                             0
# Fiji                                0
# Holy See                            0
# Mozambique                          0
# Macau                               0
# Madagascar                          0
# Namibia                             0
# Mongolia                            0
# Nepal                               0
# Laos                                0
# Grenada                             0
# Papua New Guinea                    0
# Sao Tome and Principe               0
# Seychelles                          0
# South Sudan                         0
# Uganda                              0
# Yemen                               0
# Timor-Leste                         0
# Vietnam                             0
# Western Sahara                      0
# ...

# %% [markdown]
# ### how many confirmed, deaths& recoverd cases were reeported from india till 29 april 2020

# %%
df[df['Region']=='India']
# Out:
#          Date State Region  Confirmed  Deaths  Recovered
# 74  4/29/2020   NaN  India      33062    1079       8437
